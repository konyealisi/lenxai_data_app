# %%
import pandas as pd
import re

# %%
# Read CSV file
csv_file = "C:/Users/konye/Downloads/dataUpload.csv"
df = pd.read_csv(csv_file)

# # Remove '?' from column names
# df.columns = df.columns.str.replace('?', '')

# Remove text within brackets (including the brackets) and question marks from column names
df.columns = df.columns.str.replace(r'\s*[\(\[].*?[\)\]]|\?', '', regex=True)

# Remove anything after a slash (including the slash) from column names
df.columns = df.columns.str.split('/').str[0]

# %%
def clean_dataframe(df):
    # Trim column names, convert to lowercase, and replace spaces with underscores
    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
    
    # Trim all string values in the DataFrame
    df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
    
    return df
clean_df = clean_dataframe(df)
df = clean_df.drop('s', axis=1)
df
# Out:
#    state       lga                                  facility  \
# 0   Kano  Nasarawa  Kano State One Stop Shop (OSS), Nasarawa
# 1   Kano  Nasarawa  Kano State One Stop Shop (OSS), Nasarawa
# 2   Kano  Nasarawa  Kano State One Stop Shop (OSS), Nasarawa
# 3   Kano  Nasarawa  Kano State One Stop Shop (OSS), Nasarawa
# 4   Kano  Nasarawa  Kano State One Stop Shop (OSS), Nasarawa
# 5   Kano  Nasarawa  Kano State One Stop Shop (OSS), Nasarawa
# 6   Kano  Nasarawa  Kano State One Stop Shop (OSS), Nasarawa
# 7   Kano  Nasarawa  Kano State One Stop Shop (OSS), Nasarawa
# 8   Kano  Nasarawa  Kano State One Stop Shop (OSS), Nasarawa
# 9   Kano  Nasarawa  Kano State One Stop Shop (OSS), Nasarawa
# 10   FCT      AMAC                            Abuja Hospital
#
#                               patient_id   hospital_number         unique_id  \
# 0   002cecc5-72c5-4613-84a6-3e283e36f83d  oss/kn/22/2/3353  oss/kn/22/2/3353
# 1   00385a04-5e56-419b-8d75-ac8819f662eb  OSS/KN/22/6/4343  OSS/KN/22/6/4343
# 2   0047b46d-4e6b-4df2-8414-82371c41343d  oss/kn/22/1/5059  oss/kn/22/1/5059
# 3   005b3334-9d26-40ea-8f38-9bc9976670a1  OSS/KN/19/3/0467  OSS/KN/19/3/0467
# 4   006d70da-7646-4ac3-b452-0e6e156684c1  OSS/KN/20/1/1463  OSS/KN/20/1/1463
# 5   007344ef-99b4-4149-a5fb-f446a2554a36  oss/kn/22/1/5174  oss/kn/22/1/5174
# 6   008a2685-2906-41f3-86e9-093a400cc4ee  OSS/KN/19/2/0896  OSS/KN/19/2/0896
# 7   00909910-ecd7-46ac-b9bd-36a5297ffdec    OSS/KN/18/0106    OSS/KN/18/0106
# 8   00c35622-8308-4b37-b8d1-1027fcbc64a9  OSS/KN/20/1/2556  oss/kn/20/1/2556
# 9   00d64aa5-b8cf-454a-bf14-ca6ff9d941b1  oss/kn/22/6/3554  oss/kn/22/6/3554
# 10  00d64aa5-b8cf-454a-bf14-ca6ff9d941b2   hf/fc/22/6/0034   hf/fc/22/6/0034
#
#     household_unique_no  received_ovc_service     sex  current_weight  ...  \
# 0                   NaN                   NaN    Male            71.0  ...
# 1                   NaN                   NaN    Male             NaN  ...
# 2                   NaN                   NaN  Female             NaN  ...
# 3                   NaN                   NaN    Male            74.0  ...
# 4                   NaN                   NaN  Female            70.0  ...
# 5                   NaN                   NaN  Female             NaN  ...
# 6                   NaN                   NaN  Female            58.0  ...
# 7                   NaN                   NaN    Male            66.0  ...
# 8                   NaN                   NaN  Female            60.0  ...
# 9                   NaN                   NaN    Male             NaN  ...
# 10                  NaN                   NaN    Male             NaN  ...
#
#    cervical_cancer_screening_type cervical_cancer_screening_method  \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
# 6                             NaN                              NaN
# 7                             NaN                              NaN
# 8                             NaN                              NaN
# 9                             NaN                              NaN
# 10                            NaN                              NaN
#
#    result_of_cervical_cancer_screening  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
#
#     date_of_precancerous_lesions_treatment  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
#
#    precancerous_lesions_treatment_methods date_biometrics_enrolled  \
# 0                                     NaN               07/11/2022
# 1                                     NaN                      NaN
# 2                                     NaN                      NaN
# 3                                     NaN                      NaN
# 4                                     NaN                      NaN
# 5                                     NaN                      NaN
# 6                                     NaN                      NaN
# 7                                     NaN                      NaN
# 8                                     NaN               22/11/2022
# 9                                     NaN                      NaN
# 10                                    NaN                      NaN
#
#    valid_biometrics_enrolled iit_chance date_calculated        case_manager
# 0                        Yes        NaN             NaN                 NaN
# 1                        NaN        NaN             NaN                 NaN
# 2                        NaN        NaN             NaN                 NaN
# 3                        NaN        NaN             NaN                 NaN
# 4                        NaN        NaN             NaN                 NaN
# 5                        NaN        NaN             NaN                 NaN
# 6                        NaN        NaN             NaN  Saadatu Garba Umar
# 7                        NaN        NaN             NaN                 NaN
# 8                        Yes        NaN             NaN                 NaN
# 9                        NaN        NaN             NaN                 NaN
# 10                       NaN        NaN             NaN                 NaN
#
# [11 rows x 65 columns]

# %%
# Convert DataFrame to XML
# df1 = df.copy()
# df1 = df1.drop('S/No.', axis=1)
xml_output_file = 'C:/Users/konye/Downloads/dataUpload.xml'
df.to_xml(xml_output_file, index=False, root_name='Root', row_name='Row')

# %%
# Convert DataFrame to JSON
json_output_file = 'C:/Users/konye/Downloads/dataUpload.json'
df.to_json(json_output_file, orient='records', date_format='iso')

# %%
from app import app
from models import FacilityNameItem, ClientIdItem, DataEntry, Facility

# %%
with app.app_context():
    facilities = FacilityNameItem.query.all()

    for facility in facilities:
        print(f"ID: {facility.id}, Facility Name: {facility.facility_name}")
# Out:
# ID: 1, Facility Name: Kano State One Stop Shop (OSS), Nasarawa
# ID: 2, Facility Name: Abuja Hospital

# %%
with app.app_context():
    facitems = Facility.query.all()

    for f in facitems:
        print(f"ID: {f.id}, Facility Name: {f.facility_name}, State: {f.state}, LGA: {f.lga}")
# Out:
# ID: 1, Facility Name: Kano State One Stop Shop (OSS), Nasarawa, State: Kano, LGA: Nasarawa
# ID: 2, Facility Name: Abuja Hospital, State: FCT, LGA: AMAC

# %%
with app.app_context():
    items = DataEntry.query.all()

    for f in items:
        print(f"Client ID: {f.client_id}, Facility Name: {f.facility_name}, Current(ndr)?: {f.curr_ll}")
# Out:
# Client ID: oss/kn/22/2/3353, Facility Name: Kano State One Stop Shop (OSS), Nasarawa, Current(ndr)?: yes
# Client ID: OSS/KN/22/6/4343, Facility Name: Kano State One Stop Shop (OSS), Nasarawa, Current(ndr)?: yes
# Client ID: oss/kn/22/1/5059, Facility Name: Kano State One Stop Shop (OSS), Nasarawa, Current(ndr)?: yes
# Client ID: OSS/KN/19/3/0467, Facility Name: Kano State One Stop Shop (OSS), Nasarawa, Current(ndr)?: no
# Client ID: OSS/KN/20/1/1463, Facility Name: Kano State One Stop Shop (OSS), Nasarawa, Current(ndr)?: no
# Client ID: oss/kn/22/1/5174, Facility Name: Kano State One Stop Shop (OSS), Nasarawa, Current(ndr)?: yes
# Client ID: OSS/KN/19/2/0896, Facility Name: Kano State One Stop Shop (OSS), Nasarawa, Current(ndr)?: no
# Client ID: OSS/KN/18/0106, Facility Name: Kano State One Stop Shop (OSS), Nasarawa, Current(ndr)?: no
# Client ID: oss/kn/20/1/2556, Facility Name: Kano State One Stop Shop (OSS), Nasarawa, Current(ndr)?: yes
# Client ID: oss/kn/22/6/3554, Facility Name: Kano State One Stop Shop (OSS), Nasarawa, Current(ndr)?: yes
# Client ID: hf/fc/22/6/0034, Facility Name: Abuja Hospital, Current(ndr)?: yes

# %%
with app.app_context():
    dataitems = DataEntry.query.all()

    # facility_name_choices=[item.facility_name for item in items]
    # print(facility_name_choices)
    
    # dataitem = [{'client_id': item.client_id,'laspud_po':item.laspud_po} for item in items]

    data_records = [record for record in dataitems] # if record['client_id'] == 'hf/fc/22/6/0034']
    
    for data in data_records:
        print('\n', data)
# Out:
#  <DataEntry oss/kn/22/2/3353>
#
#  <DataEntry OSS/KN/22/6/4343>
#
#  <DataEntry oss/kn/22/1/5059>
#
#  <DataEntry OSS/KN/19/3/0467>
#
#  <DataEntry OSS/KN/20/1/1463>
#
#  <DataEntry oss/kn/22/1/5174>
#
#  <DataEntry OSS/KN/19/2/0896>
#
#  <DataEntry OSS/KN/18/0106>
#
#  <DataEntry oss/kn/20/1/2556>
#
#  <DataEntry oss/kn/22/6/3554>
#
#  <DataEntry hf/fc/22/6/0034>

# %%
with app.app_context():
    items = DataEntry.query.all()

    facility_name_choices=[item.facility_name for item in items]
    print(facility_name_choices)
    
    dataitem = [{'client_id': item.client_id,'laspud_po':item.laspud_po} for item in items]

    existing = [record for record in dataitem if record['client_id'] == 'hf/fc/22/6/0034'][0]
    print('\n', existing)
    # a = existing[0]
    # print(a)
    if not  existing['laspud_po'] == '':
        print('existing Record!')
    else:
        print('nay')
# Out:
# ['Kano State One Stop Shop (OSS), Nasarawa', 'Kano State One Stop Shop (OSS), Nasarawa', 'Kano State One Stop Shop (OSS), Nasarawa', 'Kano State One Stop Shop (OSS), Nasarawa', 'Kano State One Stop Shop (OSS), Nasarawa', 'Kano State One Stop Shop (OSS), Nasarawa', 'Kano State One Stop Shop (OSS), Nasarawa', 'Kano State One Stop Shop (OSS), Nasarawa', 'Kano State One Stop Shop (OSS), Nasarawa', 'Kano State One Stop Shop (OSS), Nasarawa', 'Abuja Hospital']
#
#  {'client_id': 'hf/fc/22/6/0034', 'laspud_po': datetime.date(2023, 4, 5)}
# existing Record!

# %%
with app.app_context():
    client_ids = DataEntry.query.all(facility_name)

    for client_id in client_ids:
        print(f"ID: {client_id.id}, Client Id: {client_id.client_id}")
